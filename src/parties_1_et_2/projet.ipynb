# %% [markdown]
# # Préparation des données

# %%
import pandas as pd

full_df = pd.read_csv("../synthetic.csv")

# Mettre de coté 20% des données pour le test
test_df = full_df.sample(frac=0.2, random_state=0)
df = full_df.drop(test_df.index)

##### Q1
print("Nombre d'attributs des données :", df.columns.size - 1)

##### Q2
print(
    "Nombre des classes différentes dans les instances :",
    df["Class"].value_counts().count(),
)

##### Q3
print(
    "Nombre d'instances pour chaque classe :\n",
    df["Class"].value_counts().sort_index(),
    sep="",
)
# Out:
# Nombre d'attributs des données : 14
# Nombre des classes différentes dans les instances : 4
# Nombre d'instances pour chaque classe :
# Class
# 0    510
# 1    727
# 2    387
# 3    214
# Name: count, dtype: int64

# %%
##### Q4
import matplotlib.pyplot as plt

# Visualisation 2 à 2 de quelques attributs avec les classes
plt.scatter(df["Attr_A"], df["Attr_B"], c=df["Class"])
plt.xlabel("Attr_A")
plt.ylabel("Attr_B")
plt.title("Nuage de points de données avec des classes")
plt.show()

plt.scatter(df["Attr_A"], df["Attr_C"], c=df["Class"])
plt.xlabel("Attr_A")
plt.ylabel("Attr_C")
plt.title("Nuage de points de données avec des classes")
plt.show()

plt.scatter(df["Attr_B"], df["Attr_C"], c=df["Class"])
plt.xlabel("Attr_B")
plt.ylabel("Attr_C")
plt.title("Nuage de points de données avec des classes")
plt.show()

# %% [markdown]
# # Mise en œuvre des modèles

# %% [markdown]
# ## Arbre de décision

# %%
# Gain, entropie et la recherche du meilleur attribut pour le split avec des quartiles

from math import log2
from typing import List, Tuple

from pandas import DataFrame


def entropie(dataframe: DataFrame, attribut_cible: str = "Class") -> float:
    sum: float = 0
    total: int = len(dataframe)
    for c in dataframe[attribut_cible].value_counts():
        sum += (c / total) * log2((c / total))
    return -sum


def best_split(
    dataframe: DataFrame, a: str, attribut_cible: str = "Class"
) -> Tuple[float, float, List[DataFrame]]:
    """Calcul des détails du meilleur split pour un attribut donné

    Args:
        dataframe: le dataframe contenant les données à partitionner
        a: attribut dont on cherche à déterminer le gain
        attribut_cible: attribut que l'on souhaite prédire

    """

    sorted_data: DataFrame = dataframe.sort_values(a)

    # On calcule le quartile 1 pour le départ
    split_value: float = sorted_data[a].quantile(0.25)
    partitions: List[DataFrame] = [
        sorted_data[sorted_data[a] < split_value],
        sorted_data[sorted_data[a] >= split_value],
    ]
    gain: float = calculate_gain(dataframe, partitions, a, attribut_cible)

    for q in [0.5, 0.75]:  # On teste les quartiles 2 et 3
        q_split: float = sorted_data[a].quantile(q)
        q_low: DataFrame = sorted_data[sorted_data[a] < q_split]
        q_high: DataFrame = sorted_data[sorted_data[a] >= q_split]
        local_gain: float = calculate_gain(
            dataframe, [q_low, q_high], a, attribut_cible
        )
        if local_gain > gain:
            gain = local_gain
            split_value = q_split
            partitions = [q_low, q_high]

    return (gain, split_value, partitions)


def calculate_gain(
    dataframe: DataFrame,
    partitions: List[DataFrame],
    a: str,
    attribut_cible: str = "Class",
) -> float:
    """Calcul du gain pour un attribut donné

    Args:
        dataframe: le dataframe contenant toutes les données
        partitions: les partitions obtenues après le split
        a: attribut dont on cherche à déterminer le gain
        attribut_cible: attribut que l'on souhaite prédire

    """

    e: float = entropie(dataframe, attribut_cible)
    sum: float = 0
    total: int = len(dataframe)
    for p in partitions:
        sum += (len(p[a]) / total) * entropie(p, attribut_cible)
    return e - sum


def best_feature(
    dataframe: DataFrame, attributs: List[str], attribut_cible: str = "Class"
) -> Tuple[str, float, float, List[DataFrame]]:
    """Calcul de l'attribut (entre ceux donnés) qui donne le meilleur gain et son split

    Args:
        dataframe: le dataframe contenant toutes les données
        attributs: liste des attributs à tester
        attribut_cible: attribut que l'on souhaite prédire

    """
    attributs_copy: List[str] = attributs.copy()
    best_result: tuple = best_split(dataframe, attributs_copy[0], attribut_cible)
    best_feature_label: str = attributs_copy.pop(0)

    for a in attributs_copy:
        result = best_split(dataframe, a, attribut_cible)
        if result[0] > best_result[0]:
            best_result = result
            best_feature_label = a

    return (best_feature_label,) + best_result


def best_feature_wrapper(
    dataframe: DataFrame, attribut_cible: str = "Class"
) -> Tuple[str, float, float, List[DataFrame]]:
    """Calcul de l'attribut qui donne le meilleur gain et son split

    Calcule sur tous les attributs sauf l'attribut cible

    Args:
        dataframe: le dataframe contenant toutes les données
        attribut_cible: attribut que l'on souhaite prédire

    """
    attributs: List[str] = dataframe.columns.tolist()
    attributs.remove(attribut_cible)
    return best_feature(dataframe, attributs, attribut_cible)


print("Entropie de l'ensemble de données :", entropie(df))

feature, gain, split, partitions = best_feature_wrapper(df)
print("Meilleur attribut pour le split :", feature)
print("Gain obtenu :", gain)
print("Valeur de split :", split)
print("Nombre d'instances dans la partition 1 :", len(partitions[0]))
print("Nombre d'instances dans la partition 2 :", len(partitions[1]))
# print("Partitions obtenues :", partitions)
# Out:
# Entropie de l'ensemble de données : 1.876976207319886
# Meilleur attribut pour le split : Attr_B
# Gain obtenu : 0.16345382102161543
# Valeur de split : 10.28594336957628
# Nombre d'instances dans la partition 1 : 919
# Nombre d'instances dans la partition 2 : 919

# %%
# Les noeuds, la construction de l'arbre et l'affichage

from typing import Optional

from pandas import Series


class Noeud:
    def __init__(
        self,
        prediction: Series,
        attribut: str | None = None,
        split: float | None = None,
        fils_gauche: Optional["Noeud"] = None,
        fils_droite: Optional["Noeud"] = None,
        feuille: bool = False,
    ) -> None:
        if feuille and attribut is not None:
            raise ValueError("Une feuille ne doit pas avoir d'attribut")
        if feuille and split is not None:
            raise ValueError("Une feuille ne doit pas avoir de valeur de split")
        if not feuille and (fils_gauche is None or fils_droite is None):
            raise ValueError("Un noeud interne doit avoir deux fils")
        if not feuille and split is None:
            raise ValueError("Un noeud interne doit avoir une valeur de split")
        if not feuille and attribut is None:
            raise ValueError("Un noeud interne doit avoir un attribut")

        self.attribut = attribut
        self.split = split
        self.prediction = prediction
        self.fils_gauche = fils_gauche
        self.fils_droite = fils_droite
        self.feuille = feuille

    def node_result(self, spacing: str = "") -> str:
        s = ""
        for v in range(len(self.prediction.values)):
            s += (
                " Class "
                + str(self.prediction.index[v])
                + " Count: "
                + str(self.prediction.values[v])
                + "\n"
                + spacing
            )
        return s


def print_tree(node: Noeud | None, spacing: str = "") -> None:
    if node is None:
        return

    if node.feuille:
        print(spacing + node.node_result(spacing))
        return

    print(
        "{}[Attribute: {}  Split value: {}]".format(spacing, node.attribut, node.split)
    )

    print(spacing + "> True")
    print_tree(node.fils_gauche, spacing + "-")

    print(spacing + "> False")
    print_tree(node.fils_droite, spacing + "-")
    return


# Je ne sais pas si c'est la bonne façon de déterminer si une partition est vide
def partitions_est_vide(partitions: List[DataFrame]) -> bool:
    if len(partitions) == 0:
        return True
    for p in partitions:
        if len(p) == 0:
            return True
    return False


def construction_arbre(
    dataframe: DataFrame,
    profondeur: int,
    seuil: int,
    attributs: List[str],
    attribut_cible: str = "Class",
) -> Noeud:
    attribut, _, split, partitions = best_feature(dataframe, attributs, attribut_cible)
    prediction = dataframe[attribut_cible].value_counts()

    attributs_restants = attributs.copy()
    attributs_restants.remove(attribut)

    if (
        profondeur > seuil
        or len(attributs_restants) == 0
        or partitions_est_vide(partitions)
    ):
        return Noeud(prediction=prediction, feuille=True)

    branche_gauche = construction_arbre(
        partitions[0], profondeur + 1, seuil, attributs_restants, attribut_cible
    )
    branche_droite = construction_arbre(
        partitions[1], profondeur + 1, seuil, attributs_restants, attribut_cible
    )

    return Noeud(
        attribut=attribut,
        split=split,
        prediction=prediction,
        fils_gauche=branche_gauche,
        fils_droite=branche_droite,
    )


def construction_arbre_wrapper(
    dataframe: DataFrame, seuil: int, attribut_cible: str = "Class"
) -> Noeud:
    """Wrapper autour de la fonction de construction de l'arbre récursive

    Construit l'arbre avec tous les attributs sauf l'attribut cible

    """
    attributs = dataframe.columns.tolist()
    attributs.remove(attribut_cible)
    return construction_arbre(
        dataframe,
        0,
        seuil,
        attributs,
        attribut_cible,
    )


arbre = construction_arbre_wrapper(df, 3)
print_tree(arbre)
# Out:
# [Attribute: Attr_B  Split value: 10.28594336957628]
# > True
# -[Attribute: Attr_I  Split value: 9.614691771785136]
# -> True
# --[Attribute: Attr_F  Split value: 1011.536477696535]
# --> True
# ---[Attribute: Attr_N  Split value: 103.8980653172784]
# ---> True
# ---- Class 0 Count: 151
# ---- Class 3 Count: 9
# ---- Class 2 Count: 7
# ---- Class 1 Count: 4
# ----
# ---> False
# ---- Class 0 Count: 29
# ---- Class 3 Count: 15
# ---- Class 2 Count: 11
# ---- Class 1 Count: 3
# ----
# --> False
# ---[Attribute: Attr_E  Split value: 90.44010319091998]
# ---> True
# ---- Class 3 Count: 40
# ---- Class 1 Count: 8
# ---- Class 0 Count: 8
# ---- Class 2 Count: 2
# ----
# ---> False
# ---- Class 2 Count: 87
# ---- Class 0 Count: 53
# ---- Class 3 Count: 26
# ---- Class 1 Count: 6
# ----
# -> False
# --[Attribute: Attr_J  Split value: 96.23362324249092]
# --> True
# ---[Attribute: Attr_C  Split value: 1052.2908791696718]
# ---> True
# ---- Class 0 Count: 41
# ---- Class 1 Count: 38
# ---- Class 2 Count: 20
# ---- Class 3 Count: 16
# ----
# ---> False
# ---- Class 0 Count: 71
# ---- Class 3 Count: 38
# ---- Class 1 Count: 4
# ---- Class 2 Count: 2
# ----
# --> False
# ---[Attribute: Attr_F  Split value: 944.7450370723927]
# ---> True
# ---- Class 0 Count: 31
# ---- Class 1 Count: 23
# ---- Class 2 Count: 2
# ---- Class 3 Count: 2
# ----
# ---> False
# ---- Class 1 Count: 130
# ---- Class 0 Count: 21
# ---- Class 3 Count: 19
# ---- Class 2 Count: 2
# ----
# > False
# -[Attribute: Attr_H  Split value: 9.801908279439107]
# -> True
# --[Attribute: Attr_A  Split value: 9.562394772466423]
# --> True
# ---[Attribute: Attr_N  Split value: 86.70564725728694]
# ---> True
# ---- Class 1 Count: 53
# ---- Class 2 Count: 3
# ---- Class 0 Count: 1
# ----
# ---> False
# ---- Class 1 Count: 29
# ---- Class 2 Count: 27
# ---- Class 0 Count: 2
# ----
# --> False
# ---[Attribute: Attr_I  Split value: 9.189183882856918]
# ---> True
# ---- Class 1 Count: 62
# ---- Class 3 Count: 13
# ---- Class 0 Count: 8
# ---- Class 2 Count: 3
# ----
# ---> False
# ---- Class 1 Count: 240
# ---- Class 2 Count: 10
# ---- Class 3 Count: 4
# ---- Class 0 Count: 4
# ----
# -> False
# --[Attribute: Attr_A  Split value: 11.65143968414169]
# --> True
# ---[Attribute: Attr_N  Split value: 100.50998085520251]
# ---> True
# ---- Class 0 Count: 67
# ---- Class 2 Count: 58
# ---- Class 1 Count: 38
# ---- Class 3 Count: 9
# ----
# ---> False
# ---- Class 2 Count: 143
# ---- Class 3 Count: 23
# ---- Class 0 Count: 4
# ---- Class 1 Count: 3
# ----
# --> False
# ---[Attribute: Attr_F  Split value: 1020.9449991417944]
# ---> True
# ---- Class 0 Count: 14
# ---- Class 1 Count: 10
# ---- Class 2 Count: 5
# ----
# ---> False
# ---- Class 1 Count: 76
# ---- Class 0 Count: 5
# ---- Class 2 Count: 5
# ----

# %%
# Création des différents arbres de décision de profondeur 3 à 8 inclus

arbres: List[Noeud] = []

# Association indice de la liste à la profondeur de l'arbre
# arbres[0] = arbre de profondeur 3
# arbres[1] = arbre de profondeur 4
# ...
# arbres[5] = arbre de profondeur 8
for i in range(3, 9):
    arbres.append(construction_arbre_wrapper(df, i))

# %%
# Inférence et évaluation


from typing import cast


def inference(instance: DataFrame, noeud: Noeud) -> Series:
    if noeud.feuille:
        return noeud.prediction
    valeur_attribut: float = instance[noeud.attribut].values[0]
    # cast() est utilisé ici pour faire taire le vérificateur de type statique mypy
    # car on sait que le noeud n'est pas une feuille
    if valeur_attribut < cast(float, noeud.split):
        return inference(instance, cast(Noeud, noeud.fils_gauche))
    return inference(instance, cast(Noeud, noeud.fils_droite))


# Exemple d'erreur de classification
sample = test_df.loc[[1511]]
# sample = test_df.sample()
print(
    f"Inférence pour l'instance de label {sample['Class'].index[0]} et de class {sample['Class'].values[0]} :"
)
print(inference(sample, arbres[0]))  # Arbre de profondeur 3
print("\n")


# Evaluation de la précision sur les données de test
# pour les arbres de profondeur 3 à 8 inclus.
# Inférer chaque instance de test et comparer la prédiction
for i in range(3, 9):
    print("Profondeur de l'arbre :", i)
    correct: int = 0
    for _, row in test_df.iterrows():
        prediction = inference(row.to_frame().T, arbres[i - 3])
        if prediction.idxmax() == row["Class"]:
            correct += 1
    print("Précision :", round(correct / len(test_df) * 100, 3), "%", end="\n\n")
# Out:
# Inférence pour l'instance de label 1511 et de class 0 :
# Class
# 1    130
# 0     21
# 3     19
# 2      2
# Name: count, dtype: int64
#
#
# Profondeur de l'arbre : 3
# Précision : 70.217 %
#
# Profondeur de l'arbre : 4
# Précision : 75.435 %
#
# Profondeur de l'arbre : 5
# Précision : 76.957 %
#
# Profondeur de l'arbre : 6
# Précision : 80.0 %
#
# Profondeur de l'arbre : 7
# Précision : 75.435 %
#
# Profondeur de l'arbre : 8
# Précision : 75.0 %

# %% [markdown]
# ## Réseaux de neurones artificiels

# %%
# Encore plus de préparation des données pour le réseau de neurones

# Mettre de coté 15% des données d'entrainement pour la validation
validation_df = df.sample(frac=0.15, random_state=0)
entrainement_df = df.drop(validation_df.index)

X_raw = entrainement_df.drop(columns="Class")
y_raw = entrainement_df["Class"]

X_raw_valid = validation_df.drop(columns="Class")
y_raw_valid = validation_df["Class"]

X_raw_test = test_df.drop(columns="Class")
y_raw_test = test_df["Class"]

# Encodage one-hot
y = pd.get_dummies(y_raw)
y_valid = pd.get_dummies(y_raw_valid)
y_test = pd.get_dummies(y_raw_test)


def custom_normalize(data):  # Fonction de normalisation
    return (data - data.min()) / (data.max() - data.min())


# Appliquer la normalisation à chaque colonne
X = X_raw.apply(custom_normalize)
X_valid = X_raw_valid.apply(custom_normalize)
X_test = X_raw_test.apply(custom_normalize)

# %%
# Structure du réseau de neurones

from typing import Callable

import numpy as np
from scipy.special import softmax
from sklearn.utils import shuffle


class NeuralNet:
    def __init__(
        self,
        X_train: np.ndarray,
        y_train: np.ndarray,
        X_test: np.ndarray,
        y_test: np.ndarray,
        activation_func: Callable[[np.ndarray], Tuple[np.ndarray, np.ndarray]],
        hidden_layer_sizes: Tuple[int, ...] = (4,),
        learning_rate: float = 0.01,
        epoch: int = 200,
        patience: int = 10,
    ):
        self.X_train = X_train
        self.y_train = y_train
        self.X_test = X_test
        self.y_test = y_test
        self.hidden_layer_sizes = hidden_layer_sizes
        self.weights: List[np.ndarray] = [None] * (len(hidden_layer_sizes) + 1)  # type: ignore
        self.biases: List[np.ndarray] = [None] * (len(hidden_layer_sizes) + 1)  # type: ignore
        self.activation: List[np.ndarray] = [None] * (  # type: ignore
            len(hidden_layer_sizes) + 1
        )
        self.entrees_ponderees: List[np.ndarray] = [None] * (  # type: ignore
            len(hidden_layer_sizes) + 1
        )
        self.df: List[np.ndarray] = [None] * (len(hidden_layer_sizes) + 1)  # type: ignore
        self.activation_func = activation_func
        self.learning_rate = learning_rate
        self.epoch = epoch
        self.patience = patience
        self.__weights_init(X_train.shape[0], y_train.shape[0])
        self.__biases_init()
        self.__gradient_descent()

    def __weights_init(self, n_attributes: int, n_classes: int) -> None:
        for i in range(len(self.weights)):
            if i == 0:  # Première couche cachée juste après la couche d'entrée
                self.weights[i] = np.random.uniform(
                    low=-1.0, high=1.0, size=(self.hidden_layer_sizes[i], n_attributes)
                )
            elif i == len(self.hidden_layer_sizes):  # Couche de sortie
                self.weights[i] = np.random.uniform(
                    low=-1.0, high=1.0, size=(n_classes, self.hidden_layer_sizes[i - 1])
                )
            else:  # Couches cachées
                self.weights[i] = np.random.uniform(
                    low=-1.0,
                    high=1.0,
                    size=(self.hidden_layer_sizes[i], self.hidden_layer_sizes[i - 1]),
                )

    def __biases_init(self) -> None:
        for i in range(len(self.biases)):
            if i == len(self.biases) - 1:
                self.biases[i] = np.random.uniform(
                    low=-1.0, high=1.0, size=(self.y_train.shape[0], 1)
                )
            else:
                self.biases[i] = np.random.uniform(
                    low=-1.0, high=1.0, size=(self.hidden_layer_sizes[i], 1)
                )

    def forward_propagation(
        self, X: np.ndarray, y: np.ndarray
    ) -> Tuple[np.ndarray, float]:
        """
        Fonction de propagation avant sur toutes les couches avec les données d'entrainement
        """
        for i in range(len(self.hidden_layer_sizes) + 1):
            if i == 0:
                self.entrees_ponderees[i] = np.dot(self.weights[i], X) + self.biases[i]
                self.activation[i], self.df[i] = self.activation_func(
                    self.entrees_ponderees[i]
                )
            elif i == len(self.hidden_layer_sizes):
                self.entrees_ponderees[i] = (
                    np.dot(self.weights[i], self.activation[i - 1]) + self.biases[i]
                )
                self.activation[i] = self.softmax(self.entrees_ponderees[i])
            else:
                self.entrees_ponderees[i] = (
                    np.dot(self.weights[i], self.activation[i - 1]) + self.biases[i]
                )
                self.activation[i], self.df[i] = self.activation_func(
                    self.entrees_ponderees[i]
                )
        return self.activation[-1], self.cross_entropy_cost(self.activation[-1], y)

    def __backward_propagation(self, X: np.ndarray, y: np.ndarray) -> None:
        delta: List[np.ndarray] = [None] * (len(self.hidden_layer_sizes) + 1)  # type: ignore[assignment, list-item]
        dW: List[np.ndarray] = [None] * (len(self.hidden_layer_sizes) + 1)  # type: ignore[assignment, list-item]
        db: List[np.ndarray] = [None] * (len(self.hidden_layer_sizes) + 1)  # type: ignore[assignment, list-item]

        dW_accumulator = [np.zeros_like(W) for W in self.weights]
        db_accumulator = [np.zeros_like(b) for b in self.biases]

        # delta[-1] = self.cross_entropy_cost(self.activation[-1], y) - y
        delta[-1] = self.activation[-1] - y
        dW[-1] = delta[-1] @ self.activation[-2].T
        db[-1] = delta[-1]

        for i in reversed(range(len(self.hidden_layer_sizes))):
            delta[i] = np.multiply(self.weights[i + 1].T @ delta[i + 1], self.df[i])
            if i == 0:
                dW[i] = delta[i] @ X.T
            else:
                dW[i] = delta[i] @ self.activation[i - 1].T
            db[i] = delta[i]

            dW_accumulator[i] += dW[i]
            db_accumulator[i] += np.sum(db[i], axis=1, keepdims=True)

        for i in range(len(self.hidden_layer_sizes) + 1):
            # self.weights[i] -= self.learning_rate * dW[i]
            # self.biases[i] -= self.learning_rate * db[i]

            self.weights[i] -= self.learning_rate * dW_accumulator[i] / X.shape[1]
            self.biases[i] -= self.learning_rate * db_accumulator[i] / X.shape[1]

    def __gradient_descent(self) -> None:
        """
        Fonction de descente de gradient pour ajuster les poids et les biais
        en mini-batch de 4 instance à la fois.
        """
        erreur_train: List[float] = []
        erreur_train_moyenne: List[float] = []
        erreur_test: List[float] = []
        erreur_test_moyenne: List[float] = []
        best_val_loss = float("inf")
        epochs_without_improvement = 0
        epoch = 0

        for i in range(self.epoch):
            epoch = i
            self.X_train, self.y_train = [
                t.T for t in shuffle(self.X_train.T, self.y_train.T, random_state=0)
            ]

            erreur_train.clear()
            erreur_test.clear()

            for e in range(0, len(self.X_train), 4):
                erreur_train.append(
                    self.forward_propagation(
                        self.X_train[:, e : e + 4], self.y_train[:, e : e + 4]
                    )[1]
                )
                self.__backward_propagation(
                    self.X_train[:, e : e + 4], self.y_train[:, e : e + 4]
                )

            erreur_train_moyenne.append(sum(erreur_train) / len(erreur_train))

            for e in range(0, len(self.X_test), 4):
                erreur_test.append(
                    self.forward_propagation(
                        self.X_test[:, e : e + 4], self.y_test[:, e : e + 4]
                    )[1]
                )

            erreur_test_moyenne.append(sum(erreur_test) / len(erreur_test))

            if erreur_test_moyenne[i] < best_val_loss:
                best_val_loss = erreur_test_moyenne[i]
                epochs_without_improvement = 0
            else:
                epochs_without_improvement += 1
                if epochs_without_improvement >= self.patience:
                    print(
                        f"Early stopping à l'epoch {i}. Meilleure erreur de validation : {best_val_loss}"
                    )
                    break

        epochs = range(1, epoch + 2)
        plt.plot(epochs, erreur_train_moyenne, label="Training Error")
        plt.plot(epochs, erreur_test_moyenne, label="Testing Error")
        plt.xlabel("Epochs")
        plt.ylabel("Error")
        plt.title("Training and Validation Errors")
        plt.legend()
        plt.show()

    @staticmethod
    def tanh(Z):
        """
        Z : non activated outputs
        Returns (A : 2d ndarray of activated outputs, df: derivative component wise)
        """
        A = np.empty(Z.shape)
        A = 2.0 / (1 + np.exp(-2.0 * Z)) - 1  # A = np.tanh(Z)
        df = 1 - A**2
        return A, df

    @staticmethod
    def relu(Z):
        A = np.empty(Z.shape)
        A = np.maximum(0, Z)
        df = (Z > 0).astype(int)
        return A, df

    @staticmethod
    def softmax(Z):
        return softmax(Z, axis=0)  # depuis scipy.special

    @staticmethod
    def cross_entropy_cost(y_hat, y):
        n = y_hat.shape[1]
        ce = -np.sum(y * np.log(y_hat + 1e-9)) / n
        return ce

# %%
# Entraînement de plusieurs modèles

# tanh (10, 8, 6)
n_tan_0 = NeuralNet(
    X_train=X.to_numpy().T,
    y_train=y.to_numpy().T,
    X_test=X_valid.to_numpy().T,
    y_test=y_valid.to_numpy().T,
    activation_func=NeuralNet.tanh,
    hidden_layer_sizes=(10, 8, 6),
    learning_rate=0.01,
    epoch=10000,
    patience=4,
)

# tanh (10, 8, 4)
n_tan_1 = NeuralNet(
    X_train=X.to_numpy().T,
    y_train=y.to_numpy().T,
    X_test=X_valid.to_numpy().T,
    y_test=y_valid.to_numpy().T,
    activation_func=NeuralNet.tanh,
    hidden_layer_sizes=(10, 8, 4),
    learning_rate=0.01,
    epoch=10000,
    patience=4,
)

# tanh (6, 4)
n_tan_2 = NeuralNet(
    X_train=X.to_numpy().T,
    y_train=y.to_numpy().T,
    X_test=X_valid.to_numpy().T,
    y_test=y_valid.to_numpy().T,
    activation_func=NeuralNet.tanh,
    hidden_layer_sizes=(6, 4),
    learning_rate=0.01,
    epoch=10000,
    patience=4,
)

# relu (10, 8, 6)
n_relu_0 = NeuralNet(
    X_train=X.to_numpy().T,
    y_train=y.to_numpy().T,
    X_test=X_valid.to_numpy().T,
    y_test=y_valid.to_numpy().T,
    activation_func=NeuralNet.relu,
    hidden_layer_sizes=(10, 8, 6),
    learning_rate=0.01,
    epoch=10000,
    patience=4,
)

# relu (10, 8, 4)
n_relu_1 = NeuralNet(
    X_train=X.to_numpy().T,
    y_train=y.to_numpy().T,
    X_test=X_valid.to_numpy().T,
    y_test=y_valid.to_numpy().T,
    activation_func=NeuralNet.relu,
    hidden_layer_sizes=(10, 8, 4),
    learning_rate=0.01,
    epoch=10000,
    patience=4,
)

# relu (6, 4)
n_relu_2 = NeuralNet(
    X_train=X.to_numpy().T,
    y_train=y.to_numpy().T,
    X_test=X_valid.to_numpy().T,
    y_test=y_valid.to_numpy().T,
    activation_func=NeuralNet.relu,
    hidden_layer_sizes=(6, 4),
    learning_rate=0.01,
    epoch=10000,
    patience=4,
)
# Out:
# Early stopping à l'epoch 49. Meilleure erreur de validation : 1.3270419459245402
# Early stopping à l'epoch 29. Meilleure erreur de validation : 1.3014325253443362
# Early stopping à l'epoch 107. Meilleure erreur de validation : 1.5647591718616893
# Early stopping à l'epoch 46. Meilleure erreur de validation : 1.3513917676226437
# Early stopping à l'epoch 51. Meilleure erreur de validation : 1.349183121534248
# Early stopping à l'epoch 68. Meilleure erreur de validation : 1.5666560637590639

# %%
# print(X_test)

test_all = True
if not test_all:
    # Quelques indices d'instances
    # 712 (t), 1279 (f), 98 (f), 399 (t), 453 (t), 895 (f), 232 (f)
    loc = 232
    attr = X_test.loc[loc].to_numpy().reshape(-1, 1)
    label = y_test.loc[loc].to_numpy().reshape(-1, 1)

    print(attr)
    print(label)
    print(n_relu_2.forward_propagation(attr, label)[0])
else:
    for e in [n_tan_0, n_tan_1, n_tan_2, n_relu_0, n_relu_1, n_relu_2]:
        count = 0
        for i in X_test.index.tolist():
            attr = X_test.loc[i].to_numpy().reshape(-1, 1)
            label = y_test.loc[i].to_numpy().reshape(-1, 1)
            if label[e.forward_propagation(attr, label)[0].argmax()]:
                count += 1
        print(f"Précision pour le modèle : {round(count / len(X_test) * 100, 2)}%")
# Out:
# Précision pour le modèle : 51.3%
# Précision pour le modèle : 22.61%
# Précision pour le modèle : 7.39%
# Précision pour le modèle : 36.3%
# Précision pour le modèle : 35.65%
# Précision pour le modèle : 6.52%
